# %% [markdown]
# TUGAS 1 DATASET 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn import svm

x = [1, 1, 0, -1]
y = [1, -1, 2, -1]

X = np.array([[1,1],
             [1,-1],
             [0,2],
             [-1,-1]])
y = [1,1,1,0]

clf = svm.SVC(kernel='linear', C = 1.0)
clf.fit(X,y)

w = clf.coef_[0]
print(w)

a = -w[0] / w[1]

xx = np.linspace(-3,3)
yy = a * xx - clf.intercept_[0] / w[1]

h0 = plt.plot(xx, yy, 'k-', label="non weighted div")

plt.scatter(X[:, 0], X[:, 1], c = y)
plt.legend()
plt.show()
# Out:
# [1.    0.333]

# %% [markdown]
# TUGAS 1 DATASET 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn import svm

x = [2,3,5,6]
y = [3,4,2,3]

X = np.array([[2,3],
             [3,4],
             [5,2],
             [6,3]])
y = [1,1,1,0]

clf = svm.SVC(kernel='linear', C = 1.0)
clf.fit(X,y)

w = clf.coef_[0]
print(w)

a = -w[0] / w[1]

xx = np.linspace(0,9)
yy = a * xx - clf.intercept_[0] / w[1]

h0 = plt.plot(xx, yy, 'k-', label="non weighted div")

plt.scatter(X[:, 0], X[:, 1], c = y)
plt.legend()
plt.show()
# Out:
# [-1. -1.]

# %% [markdown]
# TUGAS 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

xx = [0.5,1,-1,-0.5]
yy = [0,-1,1,-0.5]


y = [1,1,1,1]
 
#xx, yy = np.meshgrid(np.linspace(-3, 3, 500),
                     #np.linspace(-3, 3, 500))
np.random.seed(0)
X = np.array([[0.5,0],
             [1,-1],
             [-1,1],
             [-0.5,-0.5]])
Y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# fit the model
clf = svm.NuSVC(gamma='auto')
clf.fit(X, Y)

# plot the decision function for each datapoint on the grid
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()), aspect='auto',
           origin='lower', cmap=plt.cm.PuOr_r)
contours = plt.contour(xx, yy, Z, levels=[0], linewidths=2,
                       linestyles='dashed')
plt.scatter(X[:, 0], X[:, 1], s=30, c=Y, cmap=plt.cm.Paired,
            edgecolors='k')
plt.xticks(())
plt.yticks(())
plt.axis([-3, 3, -3, 3])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-760fd24531c2> in <module>()
#      23
#      24 # plot the decision function for each datapoint on the grid
# ---> 25 Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
#      26 Z = Z.reshape(xx.shape)
#      27
#
# AttributeError: 'list' object has no attribute 'ravel'
